# %% [markdown]
# # CHECKPOINT 2

# %%
import pandas as pd

# %% [markdown]
# # DATA PREPARATION

# %% [markdown]
# - MEMUAT DATA CSV

# %%
df = pd.read_csv("/content/top-300-youtube-channels.csv")

df
# Out:
#      Unnamed: 0  Rank                Channel_Name  Subscriber_Count  \
# 0             0     1                    T-Series         237000000
# 1             1     2  Cocomelon - Nursery Rhymes         154000000
# 2             2     3                   SET India         152000000
# 3             3     4                    Sony SAB          77500000
# 4             4     5           ✿ Kids Diana Show         108000000
# ..          ...   ...                         ...               ...
# 291         295   296                Jake Fellman          15000000
# 292         296   297              DisneyJuniorUK          11300000
# 293         297   298          JTBC Entertainment           7580000
# 294         298   299                     Mnet TV           9040000
# 295         299   300                    GMA News          12900000
#
#       Video_Views  Video_Count             Genre  Channel_Started
# 0    216495600668        18831             Music             2006
# ...

# %% [markdown]
# - CEK TIPE DATA SETIAP KOLOM DAN BARIS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        296 non-null    int64
#  1   Rank              296 non-null    int64
#  2   Channel_Name      296 non-null    object
#  3   Subscriber_Count  296 non-null    int64
#  4   Video_Views       296 non-null    int64
#  5   Video_Count       296 non-null    int64
#  6   Genre             296 non-null    object
#  7   Channel_Started   296 non-null    int64
# dtypes: int64(6), object(2)
# memory usage: 18.6+ KB

# %% [markdown]
# - CEK JUMLAH BARIS DAN KOLOM

# %%
df.shape
# Out:
# (296, 8)

# %% [markdown]
# - STATISTIK DESKRIPTIF

# %%
df.describe()
# Out:
#        Unnamed: 0        Rank  Subscriber_Count   Video_Views    Video_Count  \
# count  296.000000  296.000000      2.960000e+02  2.960000e+02     296.000000
# mean   149.760135  150.760135      3.159155e+07  2.199628e+10   19174.331081
# std     86.813964   86.813964      2.471406e+07  1.942543e+10   46072.700205
# min      0.000000    1.000000      3.720000e+06  1.138766e+10      15.000000
# 25%     74.750000   75.750000      1.737500e+07  1.357843e+10     386.250000
# 50%    150.500000  151.500000      2.570000e+07  1.633676e+10    1984.500000
# 75%    224.250000  225.250000      3.675000e+07  2.284494e+10    8558.000000
# max    299.000000  300.000000      2.370000e+08  2.164956e+11  345736.000000
#
#        Rata_Rata_Views_per_Video
# count               2.960000e+02
# mean                4.949723e+07
# std                 1.128093e+08
# min                 3.293745e+04
# 25%                 2.086546e+06
# 50%                 1.071409e+07
# 75%                 4.642309e+07
# ...

# %% [markdown]
# - ANALISIS KORELASI

# %%
corr_matrix = df[["Video_Views", "Video_Count"]].corr()

# %%
print("\nMatriks Korelasi:")
print(corr_matrix)
# Out:
# Matriks Korelasi:
#              Video_Views  Video_Count
# Video_Views     1.000000     0.056575
# Video_Count     0.056575     1.000000

# %% [markdown]
# - MENUNJUKKAN HANYA KOLOM NUMERIC

# %%
df.std(numeric_only=True)
# Out:
# Unnamed: 0          8.681396e+01
# Rank                8.681396e+01
# Subscriber_Count    2.471406e+07
# Video_Views         1.942543e+10
# Video_Count         4.607270e+04
# Channel_Started     3.997822e+00
# dtype: float64

# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# MISSING VALUES

# %% [markdown]
# - MELIHAT MISSING VALUES

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Unnamed: 0          0.0
# Rank                0.0
# Channel_Name        0.0
# Subscriber_Count    0.0
# Video_Views         0.0
# Video_Count         0.0
# Genre               0.0
# Channel_Started     0.0
# dtype: float64

# %% [markdown]
# - Melakukan pengecekan nilai kosong pada kolom Subscriber_Count

# %%
df[df['Subscriber_Count'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Rank, Channel_Name, Subscriber_Count, Video_Views, Video_Count, Genre, Channel_Started]
# Index: []

# %% [markdown]
# - Melakukan pengecekan nilai kosong pada kolom Video_Views

# %%
df[df['Video_Views'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Rank, Channel_Name, Subscriber_Count, Video_Views, Video_Count, Genre, Rata_Rata_Views_per_Video]
# Index: []

# %% [markdown]
# - Melakukan pengecekan nilai kosong pada kolom Video_Count

# %%
df[df['Video_Count'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Rank, Channel_Name, Subscriber_Count, Video_Views, Video_Count, Genre, Channel_Started]
# Index: []

# %% [markdown]
# - MELAKUKAN PENGECEKAN TERHADAP DATA YANG GANDA ATAU DUPLIKAT

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Rank, Channel_Name, Subscriber_Count, Video_Views, Video_Count, Genre, Channel_Started]
# Index: []

# %% [markdown]
# - MENEMUKAN NILAI OUTLIERS

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom             Persentase Outliers
# Unnamed: 0                   0.000000
# Rank                         0.000000
# Subscriber_Count             6.418919
# Video_Views                  7.432432
# Video_Count                 18.918919
# Channel_Started              0.000000

# %% [markdown]
# - INCONSISTENT VALUES
#
# MENURUT SAYA DATASET YANG SAYA GUNAKAN TIDAK MEMILIKI NILAI YANG TIDAK KONSISTEN

# %% [markdown]
# ### TERBUKTI BAHWA TIDAK ADA DATA ANOMALI DAN DATA DUPLIKAT SEHINGGA TIDAK PERLU DITANGANI ATAU DIPERBAIKI

# %% [markdown]
# # CONSTRUCT DATA

# %% [markdown]
# - MENAMBAH KOLOM Rata_Rata_Views_per_Video

# %%
df["Rata_Rata_Views_per_Video"] = df["Video_Views"] / df["Video_Count"]

df

print(df.head())
# Out:
#    Unnamed: 0  Rank                Channel_Name  Subscriber_Count  \
# 0           0     1                    T-Series         237000000
# 1           1     2  Cocomelon - Nursery Rhymes         154000000
# 2           2     3                   SET India         152000000
# 3           3     4                    Sony SAB          77500000
# 4           4     5           ✿ Kids Diana Show         108000000
#
#     Video_Views  Video_Count             Genre  Rata_Rata_Views_per_Video
# 0  216495600668        18831             Music               1.149677e+07
# 1  152638999634          861         Education               1.772811e+08
# 2  140138068504       105649  Film & Animation               1.326450e+06
# 3   92952274861        65028  Film & Animation               1.429419e+06
# 4   88452629066         1070    People & Blogs               8.266601e+07

# %% [markdown]
# - MENUNJUKKAN DATA YANG SUDAH DITAMBAHKAN DATA BARU

# %%
df
# Out:
#      Unnamed: 0  Rank                Channel_Name  Subscriber_Count  \
# 0             0     1                    T-Series         237000000
# 1             1     2  Cocomelon - Nursery Rhymes         154000000
# 2             2     3                   SET India         152000000
# 3             3     4                    Sony SAB          77500000
# 4             4     5           ✿ Kids Diana Show         108000000
# ..          ...   ...                         ...               ...
# 291         295   296                Jake Fellman          15000000
# 292         296   297              DisneyJuniorUK          11300000
# 293         297   298          JTBC Entertainment           7580000
# 294         298   299                     Mnet TV           9040000
# 295         299   300                    GMA News          12900000
#
#       Video_Views  Video_Count             Genre  Rata_Rata_Views_per_Video
# ...

# %% [markdown]
# # DATA REDUCTION

# %% [markdown]
# - MENGHAPUS DATA YANG TIDAK PENTING

# %%
df = df.drop('Channel_Started', axis=1)

# %% [markdown]
# - MENUNJUKKAN DATA YANG SUDAH DIPERBARUI

# %%
df
# Out:
#      Unnamed: 0  Rank                Channel_Name  Subscriber_Count  \
# 0             0     1                    T-Series         237000000
# 1             1     2  Cocomelon - Nursery Rhymes         154000000
# 2             2     3                   SET India         152000000
# 3             3     4                    Sony SAB          77500000
# 4             4     5           ✿ Kids Diana Show         108000000
# ..          ...   ...                         ...               ...
# 291         295   296                Jake Fellman          15000000
# 292         296   297              DisneyJuniorUK          11300000
# 293         297   298          JTBC Entertainment           7580000
# 294         298   299                     Mnet TV           9040000
# 295         299   300                    GMA News          12900000
#
#       Video_Views  Video_Count             Genre
# 0    216495600668        18831             Music
# 1    152638999634          861         Education
# ...
